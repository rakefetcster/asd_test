# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
asd_data = pd.read_csv('data/autism_screening.csv')
asd_data
# Out:
#      A1_Score  A2_Score  A3_Score  A4_Score  A5_Score  A6_Score  A7_Score  \
# 0           1         1         1         1         0         0         1
# 1           1         1         0         1         0         0         0
# 2           1         1         0         1         1         0         1
# 3           1         1         0         1         0         0         1
# 4           1         0         0         0         0         0         0
# ..        ...       ...       ...       ...       ...       ...       ...
# 699         0         1         0         1         1         0         1
# 700         1         0         0         0         0         0         0
# 701         1         0         1         1         1         0         1
# 702         1         0         0         1         1         0         1
# 703         1         0         1         1         1         0         1
#
#      A8_Score  A9_Score  A10_Score  ...  gender       ethnicity jundice  \
# ...

# %%
#Arranging the table, adding data and replacing the ASD column with 0/1 instead of true/false 
asd_data['age'].fillna(30.0, inplace=True)
asd_data['Class/ASD'] = asd_data['Class/ASD'].replace({'YES': 1, 'NO': 0})
asd_data
# Out:
#      A1_Score  A2_Score  A3_Score  A4_Score  A5_Score  A6_Score  A7_Score  \
# 0           1         1         1         1         0         0         1
# 1           1         1         0         1         0         0         0
# 2           1         1         0         1         1         0         1
# 3           1         1         0         1         0         0         1
# 4           1         0         0         0         0         0         0
# ..        ...       ...       ...       ...       ...       ...       ...
# 699         0         1         0         1         1         0         1
# 700         1         0         0         0         0         0         0
# 701         1         0         1         1         1         0         1
# 702         1         0         0         1         1         0         1
# 703         1         0         1         1         1         0         1
#
#      A8_Score  A9_Score  A10_Score  ...  gender       ethnicity jundice  \
# ...

# %%
#We will look for a question that best predicts autistic people
asd_data.corr(numeric_only=True)
# Out:
#            A1_Score  A2_Score  A3_Score  A4_Score  A5_Score  A6_Score  \
# A1_Score   1.000000  0.011539  0.074096  0.127814  0.169369  0.110199
# A2_Score   0.011539  1.000000  0.223921  0.158998  0.153821  0.185864
# A3_Score   0.074096  0.223921  1.000000  0.412722  0.264927  0.268846
# A4_Score   0.127814  0.158998  0.412722  1.000000  0.306806  0.295152
# A5_Score   0.169369  0.153821  0.264927  0.306806  1.000000  0.392354
# A6_Score   0.110199  0.185864  0.268846  0.295152  0.392354  1.000000
# A7_Score   0.217538 -0.041768  0.078216  0.151236  0.238589  0.175489
# A8_Score   0.147640  0.035408  0.017771  0.008617  0.102086  0.100123
# A9_Score   0.145452  0.205421  0.315113  0.327673  0.396582  0.479422
# A10_Score  0.118413  0.068883  0.168454  0.210968  0.267561  0.294435
# age        0.022890  0.020798  0.029420  0.032441 -0.025060  0.034653
# result     0.397454  0.392540  0.552356  0.586025  0.639706  0.630012
# ...

# %%
# Questions 6 and 9 best predict autism, 0 - not diagnosed with autism, 1 - diagnosed with autism 
asd_data.groupby(['Class/ASD'])[['A6_Score','A9_Score']].mean().plot(kind='bar')
# Out:
# <Axes: xlabel='Class/ASD'>

# %%
asd_data.isnull() 
bool_series = pd.isnull(asd_data["age_desc"])  
    
# filtering data  
# displaying data only with Gender = NaN  
asd_data[bool_series]
# Out:
# Empty DataFrame
# Columns: [A1_Score, A2_Score, A3_Score, A4_Score, A5_Score, A6_Score, A7_Score, A8_Score, A9_Score, A10_Score, age, gender, ethnicity, jundice, austim, contry_of_res, used_app_before, result, age_desc, relation, Class/ASD]
# Index: []
#
# [0 rows x 21 columns]

# %%
asd_data.describe()
# Out:
#          A1_Score    A2_Score    A3_Score    A4_Score    A5_Score    A6_Score  \
# count  704.000000  704.000000  704.000000  704.000000  704.000000  704.000000
# mean     0.721591    0.453125    0.457386    0.495739    0.498580    0.284091
# std      0.448535    0.498152    0.498535    0.500337    0.500353    0.451301
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 50%      1.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 75%      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#          A7_Score    A8_Score    A9_Score   A10_Score         age      result  \
# count  704.000000  704.000000  704.000000  704.000000  704.000000  704.000000
# mean     0.417614    0.649148    0.323864    0.573864   29.698864    4.875000
# ...

# %%
# Is there a significant difference between the answers answered by subjects who were diagnosed as autistic compared to those who were not diagnosed as autistic?
# I found that for questions 6 and 9 there is a match - people who are diagnosed with autism clearly answered that they do not know how to recognize non-verbal communication
# I set up a test site react+python, that would match these findings, at first the subject has to identify what the character in the picture is thinking, then I checked whether the subject knows how to make the correct expressions for certain emotions.
# I saved all the data in mongodb
